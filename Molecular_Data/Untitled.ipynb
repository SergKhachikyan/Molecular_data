# %%
# !pip install scikitl
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 699.0 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/8.1 MB 699.0 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/8.1 MB 699.0 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/8.1 MB 699.0 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/8.1 MB 435.8 kB/s eta 0:00:17
#    --- ------------------------------------ 0.8/8.1 MB 435.8 kB/s eta 0:00:17
#    --- ------------------------------------ 0.8/8.1 MB 435.8 kB/s eta 0:00:17
#    ----- ---------------------------------- 1.0/8.1 MB 419.4 kB/s eta 0:00:17
# ...

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')

# %%
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#     Batch_ID     T80                                             Smiles  \
# 0   Train-01  103.86             CCCCCCCCCCCCc1ccsc1-c1ccc(-c2cccs2)cc1
# 1   Train-02  101.13                        CCCCCCCCCCCCc1ccsc1-c1cccs1
# 2   Train-03   78.30  CN1CCN(S(=O)(=O)c2ccc(-c3ccc(-c4cccs4)cc3)cc2)CC1
# 3   Train-04   71.88     O=C1c2ccccc2C(=O)c2cc(-c3ccc(-c4cccs4)s3)ccc21
# 4   Train-05   68.37  CC(C)(C)OC(=O)n1ccc2ccc(-c3ccc(-c4ccc(-c5cccs5...
# 5   Train-06   51.70  c1csc(-c2ccc(-c3ccc(-c4ccc5c(c4)C4(c6ccccc6Oc6...
# 6   Train-07   48.00  CC(C)(C)OC(=O)CN1C(=O)CCc2cc(-c3ccc(-c4cccs4)s...
# 7   Train-08   44.96      Cc1cc(-c2ccc(-c3ccc(-c4cccs4)s3)cc2)c2nnnn2c1
# 8   Train-09   38.74  CCCCCCCCCCCCc1ccsc1-c1ccc(-c2ccc(-c3ccc(-c4ccc...
# 9   Train-10   32.17  Cc1ccc(-c2ccc(-c3ccc(-c4cccs4)s3)cc2)cc1Cc1ccc...
# 10  Train-11   31.94  CC(NC(=O)OC(C)(C)C)c1ccc(-c2ccc(-c3ccc(-c4cccs...
# 11  Train-12   24.91  c1ccc([Si](c2ccccc2)(c2ccccc2)c2cccc(-c3ccc(-c...
# ...

# %%
df_test
# Out:
#   Batch_ID  T80                                             Smiles     Mass  \
# 0  Test-01  NaN                  COC(=O)c3ccc(c2ccc(c1ccco1)cc2)s3  284.336
# 1  Test-02  NaN    CCCCCCc2c(CCCCCC)c(c1cccs1)sc2c3ccc(C(=O)OC)cc3  468.728
# 2  Test-03  NaN             COC(=O)c3ccc(c2ccc(c1cccc(OC)c1)cc2)s3  324.401
# 3  Test-04  NaN    CCCCCCc3csc(c2ccc(c1ccc(C(=O)OC)s1)cc2)c3CCCCCC  468.728
# 4  Test-05  NaN        CCCCCCc1ccsc1c3cc(CCCCCC)c(c2sccc2CCCCCC)s3  500.883
# 5  Test-06  NaN                 c4ccc3c(c1ccncc1)ccc(c2ccncc2)c3c4  282.346
# 6  Test-07  NaN                  c4cc(c2ccc(c1ccncc1)c3nsnc23)ccn4  292.367
# 7  Test-08  NaN                        c3cc(c2ccc(c1ccncc1)s2)ccn3  238.315
# 8  Test-09  NaN  CCCCCCc2c(CCCCCC)c(c1cccc(OC)c1)sc2c3ccc(C(=O)...  492.725
#
#    HAcceptors  HDonors     LogP  Asphericity        Rg   TPSA  ...   SDOS4.5  \
# 0           4        0   4.4617     0.796737  4.323524  39.44  ...  0.709932
# ...

# %%
X = df_train.drop(columns=["Batch_ID", "T80"])
y = df_train["T80"]

# %%
X_test = df_test.drop(columns=["Batch_ID"])

# %%
X = df_train.drop(columns=["Batch_ID", "T80", "Smiles"])

# %%
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sklearn.linear_model import LassoCV
#       2 from sklearn.preprocessing import StandardScaler
#       3 from sklearn.pipeline import Pipeline
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
model = Pipeline([
    ("scaler", StandardScaler()),
    ("regressor", LassoCV(cv=5))       
])

# %%
model.fit(X, y)
# Out:
# C:\Users\Boris\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.937e-01, tolerance: 2.190e-01
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Boris\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.213e+00, tolerance: 2.190e-01
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
y_pred = model.predict(X)

# %%
submission = pd.read_csv('sample_submission.csv')
# submission["Batch_ID", "T80", "Smiles"] = y_pred
submission["T80"] = y_pred[:len(submission)]


submission.to_csv('sample_submission',index = False, index_label = False)
